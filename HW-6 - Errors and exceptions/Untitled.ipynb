# %%
from datetime import datetime, timedelta
new_date_list = []
start_date = datetime.strptime('2002-01-01','%Y-%m-%d')
end_date = datetime.strptime('2003-01-01','%Y-%m-%d')
#     print(start_date, end_date)
#     print(start_date - end_date)
while start_date < end_date:
    new_date_list.append(datetime.strftime(start_date,'%Y-%m-%d')) 
    start_date += timedelta(days = 1)
    print(new_date_list)
#             new_date_list.append(start_date.datetime('%Y-%m-%d'))
#             start_date += 1
# Out:
# ['2002-01-01']
# ['2002-01-01', '2002-01-02']
# ['2002-01-01', '2002-01-02', '2002-01-03']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05', '2002-01-06']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05', '2002-01-06', '2002-01-07']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05', '2002-01-06', '2002-01-07', '2002-01-08']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05', '2002-01-06', '2002-01-07', '2002-01-08', '2002-01-09']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05', '2002-01-06', '2002-01-07', '2002-01-08', '2002-01-09', '2002-01-10']
# ['2002-01-01', '2002-01-02', '2002-01-03', '2002-01-04', '2002-01-05', '2002-01-06', '2002-01-07', '2002-01-08', '2002-01-09', '2002-01-10', '2002-01-11']
# ...
